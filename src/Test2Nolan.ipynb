# %%
from matplotlib import pyplot as plt
import numpy as np
from sklearn.datasets import fetch_california_housing
import seaborn as sns

california_housing = fetch_california_housing(as_frame=True).frame
california_housing_without_geo = california_housing.drop(columns=["Longitude", "Latitude", ])

# %%
plt.figure(figsize=(10,10))
sns.heatmap(california_housing_without_geo.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot: >

# %%
house_val = california_housing.MedHouseVal[california_housing.MedHouseVal < 3]
sns.displot(house_val)
print("Skewness: %f" % house_val.skew())
print("Kurtosis: %f" % house_val.kurt())
# Out:
# Skewness: 0.190491
# Kurtosis: -0.911221
